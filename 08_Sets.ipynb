# %% [markdown]
# # Python sets

# %% [markdown]
# ## Definition

# %% [markdown]
# - Sets are a `mutable collection` of distinct (unique) `immutable values` that are `unordered`.
# - sets are highly useful to efficiently remove duplicate values from a list or tuple and to perform common math operations like unions and intersections.

# %% [markdown]
# ## Examples

# %%
a = set()
print(a)
print(type(a))
# Out:
# set()
# <class 'set'>

# %%
a = set((1,2,3,4,5,6))
print(a)
print(type(a))
# Out:
# {1, 2, 3, 4, 5, 6}
# <class 'set'>

# %%
a = set((1,2,3,4,5,6,2,3,4))
print(a)
print(type(a))
# Out:
# {1, 2, 3, 4, 5, 6}
# <class 'set'>

# %%
a = set((1,"abc",(1,2,3),12.3,3+2j))
print(a)
print(type(a))
# Out:
# {1, 'abc', (3+2j), (1, 2, 3), 12.3}
# <class 'set'>

# %%
a = set((1,"abc",(1,2,3),12.3,3+2j,[1,2,3]))
print(a)
print(type(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dt/34mh0kcs6vb1yfxmbqn51tm00000gp/T/ipykernel_13183/4088962980.py in <module>
# ----> 1 a = set((1,"abc",(1,2,3),12.3,3+2j,[1,2,3]))
#       2 print(a)
#       3 print(type(a))
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ### set methods

# %%
a = set((1,2,3))
print(a)
# Out:
# {1, 2, 3}

# %%
print(dir(a))
# Out:
# ['__and__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %% [markdown]
# #### add

# %%
a = set((1,2,3))
print(a)
# Out:
# {1, 2, 3}

# %%
a.add(10)
print(a)
# Out:
# {10, 1, 2, 3}

# %% [markdown]
# #### remove

# %%
a.remove(1)

# %%
print(a)
# Out:
# {10, 2, 3}

# %%
a.remove(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/dt/34mh0kcs6vb1yfxmbqn51tm00000gp/T/ipykernel_13183/686191141.py in <module>
# ----> 1 a.remove(100)
#
# KeyError: 100

# %% [markdown]
# #### pop

# %%
a = set((1,2,3))
print(a)

# %%
print(a)

# %%
a.pop()

# %% [markdown]
# #### clear

# %% [markdown]
# ## frozenset

# %% [markdown]
# ### Definition

# %% [markdown]
# - A frozenset object is a set that, once created, cannot be changed. We create a frozenset in Python using the `frozenset([iterable])`

# %%
a = frozenset((1,2,3))
print(a)
print(type(a))

# %%
a.add(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dt/34mh0kcs6vb1yfxmbqn51tm00000gp/T/ipykernel_13183/867292535.py in <module>
# ----> 1 a.add(a)
#
# TypeError: unhashable type: 'set'

# %% [markdown]
# ### frozenset methods

# %%
print(dir(a))

# %% [markdown]
# ## Set operations

# %% [markdown]
# ### union

# %% [markdown]
# <div> <img src="attachment:image-2.png" width="500"/> </div>

# %%
a = {1,2,3}
b = {1,4,5,6}
print(a)
print(b)

# %%
print(dir(a))
# Out:
# ['__and__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
a|b # | or operator
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dt/34mh0kcs6vb1yfxmbqn51tm00000gp/T/ipykernel_13183/587240338.py in <module>
# ----> 1 a|b # | or operator
#
# NameError: name 'b' is not defined

# %%
a.union(b)

# %% [markdown]
# ### intersection

# %% [markdown]
# <div> <img src="attachment:image.png" width="500"/> </div>

# %%
a = {1,2,3}
b = {1,4,5,6}
print(a)
print(b)

# %%
a&b

# %%
a.intersection(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dt/34mh0kcs6vb1yfxmbqn51tm00000gp/T/ipykernel_13183/4123925746.py in <module>
# ----> 1 a.intersection(b)
#
# NameError: name 'b' is not defined

# %% [markdown]
# ### difference

# %% [markdown]
# <div> <img src="attachment:image.png" width="500"/> </div>

# %%
a = {1,2,3}
b = {1,4,5,6}
print(a)
print(b)

# %%
a-b

# %%
a.difference(b)

# %% [markdown]
# ### symmetric difference

# %% [markdown]
# <div> <img src="attachment:image.png" width="500"/> </div>

# %%
a = {1,2,3}
b = {1,4,5,6}
print(a)
print(b)
# Out:
# {1, 2, 3}
# {1, 4, 5, 6}

# %%
a^b
# Out:
# {2, 3, 4, 5, 6}

# %%
a.symmetric_difference(b)
# Out:
# {2, 3, 4, 5, 6}

# %%
print(a|b)
print(a&b)
print(a-b)
print(a^b)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1}
# {2, 3}
# {2, 3, 4, 5, 6}

# %% [markdown]
# ### isdisjoint

# %%
a = {1,2,3}
b = {1,4,5,6}
print(a)
print(b)
# Out:
# {1, 2, 3}
# {1, 4, 5, 6}

# %%
a.isdisjoint(b)
# Out:
# False

# %%
a = {1,2,3}
b = {4,5,6}
print(a)
print(b)
# Out:
# {1, 2, 3}
# {4, 5, 6}

# %%
a.isdisjoint(b)
# Out:
# True

# %% [markdown]
# ### issubset

# %%
a = {1,2,3}
b = {1,4,5,6}
print(a)
print(b)
# Out:
# {1, 2, 3}
# {1, 4, 5, 6}

# %%
a.issubset(b)
# Out:
# False

# %%
b.issubset(a)
# Out:
# False

# %%
a = {1,2,3}
b = {1,2}
print(a)
print(b)
# Out:
# {1, 2, 3}
# {1, 2}

# %%
a.issubset(b)
# Out:
# False

# %%
b.issubset(a)
# Out:
# True

# %% [markdown]
# ### issuperset

# %%
a = {1,2,3}
b = {1,2}
print(a)
print(b)
# Out:
# {1, 2, 3}
# {1, 2}

# %%
b.issuperset(a)
# Out:
# False

# %%
a.issuperset(b)
# Out:
# True
